# %% [markdown]
# <a href="https://colab.research.google.com/github/NoobCoder-dweeb/AI-HandsOn-Journey/blob/main/notes/PPO_using_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q torch==1.13.0 swig gym==0.18.0
# Out:
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions.categorical import Categorical

class PPOMemory:
  def __init__(self, batch_size):
    self.states = []
    self.probs = []
    self.vals = []
    self.actions = []
    self.rewards = []
    self.dones = []

    self.batch_size = batch_size

  def generate_batches(self):
    n_states = len(self.states)
    batch_start = np.arange(0, n_states, self.batch_size)
    indices = np.arange(n_states, dtype=np.int32)
    np.random.shuffle(indices)
    batches = [indices[i:i+self.batch_size] for i in batch_start]

    return np.array(self.states),\
           np.array(self.actions),\
           np.array(self.probs),\
           np.array(self.vals),\
           np.array(self.rewards),\
           np.array(self.dones),\
           batches

  def store_memory(self, state, action, probs, vals, reward, done):
    self.states.append(state)
    self.actions.append(action)
    self.probs.append(probs)
    self.vals.append(vals)
    self.rewards.append(reward)
    self.dones.append(done)

  def clear_memory(self):
    self.states = []
    self.probs = []
    self.vals = []
    self.actions = []
    self.rewards = []


class ActorNetwork(nn.Module):
  def __init__(self, n_actions, input_dims, alpha,
               fc1_dims=256, fc2_dims=256, chkpt_dir='tmp/ppo'):
    super(ActorNetwork, self).__init__()
    self.checkpoint_file = os.path.join(chkpt_dir, 'actor_torch_ppo')
    self.actor = nn.Sequential(
        nn.Linear(*input_dims, fc1_dims),
        nn.ReLU(),
        nn.Linear(fc1_dims, fc2_dims),
        nn.ReLU(),
        nn.Linear(fc2_dims, n_actions),
        nn.Softmax(dim=-1)
    )
    self.optimizer = optim.Adam(self.parameters(), lr=alpha)
    self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    self.to(self.device)

  def forward(self, state):
    dist = self.actor(state)
    dist = Categorical(dist)
    return dist

  def save_checkpoint(self):
    torch.save(self.state_dict(), self.checkpoint_file)

  def load_checkpoint(self):
    self.load_state_dict(torch.load(self.checkpoint_file))

class CriticNetwork(nn.Module):
  def __init__(self, input_dims, alpha, fc1_dims=256, fc2_dims=256, chkpt_dir='tmp/ppo'):
    super(CriticNetwork, self).__init__()

    self.checkpoint_file = os.path.join(chkpt_dir, 'critic_torch_ppo')
    self.critic = nn.Sequential(
        nn.Linear(*input_dims, fc1_dims),
        nn.ReLU(),
        nn.Linear(fc1_dims, fc2_dims),
        nn.ReLU(),
        nn.Linear(fc2_dims, 1)
    )
    self.optimizer = optim.Adam(self.parameters(), lr=alpha)
    self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    self.to(self.device)

  def forward(self, state):
    return self.critic(state)

  def save_checkpoint(self):
    torch.save(self.state_dict(), self.checkpoint_file)

  def load_checkpoint(self):
    self.load_state_dict(torch.load(self.checkpoint_file))


class Agent:
  def __init__(self, input_dims, n_actions, gamma=0.99, alpha=0.0003, gae_lambda=0.95,
               policy_clip=0.2, batch_size=64, N=2048, n_epochs=10):
    self.gamma = gamma
    self.policy_clip = policy_clip
    self.n_epochs = n_epochs
    self.gae_lambda = 0.95
    self.batch_size = batch_size

    self.actor = ActorNetwork(n_actions, input_dims, alpha)
    self.critic = CriticNetwork(input_dims, alpha)
    self.memory = PPOMemory(batch_size)

  def remember(self, state, action, probs, vals, reward, done):
    self.memory.store_memory(state, action, probs, vals, reward, done)

  def save_models(self):
    print("Saving....")
    self.actor.save_checkpoint()
    self.critic.save_checkpoint()

  def load_models(self):
    print("Loading....")
    self.actor.load_checkpoint()
    self.critic.load_checkpoint()

  def choose_action(self, observation):
    state = torch.tensor([observation], dtype=torch.float).to(self.actor.device)
    dist = self.actor(state)
    value = self.critic(state)
    action = dist.sample()

    probs = torch.squeeze(dist.log_prob(action)).item()
    action = torch.squeeze(action).item()
    value = torch.squeeze(value).item()

    return action, probs, value

  def learn(self):
    for _ in range(self.n_epochs):
      state_arr, action_arr, old_probs_arr, vals_arr, \
      reward_arr, dones_arr, batches = \
        self.memory.generate_batches()

      values = vals_arr
      advantage = np.zeros(len(reward_arr), dtype=np.float32)

      for t in range(len(reward_arr) - 1):
        discount = 1
        a_t = 0
        for k in range(t, len(reward_arr) - 1):
          a_t += discount * (reward_arr[k] + self.gamma * values[k + 1] * (1 - int(dones_arr[k])) - values[k])
          discount *= self.gamma * self.gae_lambda
        advantage[t] = a_t

      advantage = torch.tensor(advantage).to(self.actor.device)
      values = torch.tensor(values).to(self.actor.device)

      for batch in batches:
        states = torch.tensor(state_arr[batch], dtype=torch.float).to(self.actor.device)
        old_probs = torch.tensor(old_probs_arr[batch], dtype=torch.float).to(self.actor.device)
        actions = torch.tensor(action_arr[batch]).to(self.actor.device)

        dist = self.actor(states)
        critic_value = self.critic(states)

        critic_value = torch.squeeze(critic_value)

        new_probs = dist.log_prob(actions)
        prob_ratio = new_probs.exp() / old_probs.exp()
        # prob_ratio = (new_probs - old_probs).exp()
        weighted_probs = advantage[batch] * prob_ratio
        weighted_clipped_probs = torch.clamp(prob_ratio, 1 - self.policy_clip, 1 + self.policy_clip) \
        * advantage[batch]
        actor_loss = -torch.min(weighted_probs, weighted_clipped_probs).mean()

        returns = advantage[batch] + values[batch]
        critic_loss = (returns - critic_value) ** 2
        critic_loss = critic_loss.mean()
        total_loss = actor_loss + 0.5*critic_loss
        self.actor.optimizer.zero_grad()
        total_loss.backward()
        self.actor.optimizer.step()
        self.critic.optimizer.step()

      self.memory.clear_memory()


import gym

if __name__ == '__main__':
  env = gym.make("CartPole-v1")
  N = 20
  batch_size = 5
  n_epochs = 4
  alpha = 0.0003
  agent = Agent(n_actions=env.action_space.n, batch_size=batch_size,
                alpha=alpha, n_epochs=n_epochs, input_dims=env.observation_space.shape)
  n_games = 300

  best_score = env.reward_range[0]
  score_history = []

  learn_iters = 0
  avg_score = 0
  n_steps = 0

  for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    while not done:
      action, prob, val = agent.choose_action(observation)
      observation_, reward, done, info = env.step(action)
      n_steps += 1
      score += reward
      agent.remember(observation, action, prob, val, reward, done)
      if n_steps % N == 0:
        agent.learn()
        learn_iters += 1
      observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
      best_score = avg_score
      agent.save_models()

    print('episode', i, f'score {score:.1f}', f"avg score {avg_score: .1f}", \
          "time steps", n_steps, "learning_steps", learn_iters)
# Out:
# Saving....
# episode 0 score 41.0 avg score  41.0 time steps 41 learning_steps 2
# episode 1 score 34.0 avg score  37.5 time steps 75 learning_steps 3
# episode 2 score 15.0 avg score  30.0 time steps 90 learning_steps 4
# episode 3 score 23.0 avg score  28.2 time steps 113 learning_steps 5
# episode 4 score 36.0 avg score  29.8 time steps 149 learning_steps 7
# episode 5 score 16.0 avg score  27.5 time steps 165 learning_steps 8
# episode 6 score 11.0 avg score  25.1 time steps 176 learning_steps 8
# episode 7 score 11.0 avg score  23.4 time steps 187 learning_steps 9
# episode 8 score 22.0 avg score  23.2 time steps 209 learning_steps 10
# episode 9 score 19.0 avg score  22.8 time steps 228 learning_steps 11
# episode 10 score 32.0 avg score  23.6 time steps 260 learning_steps 13
# episode 11 score 9.0 avg score  22.4 time steps 269 learning_steps 13
# episode 12 score 18.0 avg score  22.1 time steps 287 learning_steps 14
# episode 13 score 16.0 avg score  21.6 time steps 303 learning_steps 15
# episode 14 score 17.0 avg score  21.3 time steps 320 learning_steps 16
# episode 15 score 18.0 avg score  21.1 time steps 338 learning_steps 16
# episode 16 score 29.0 avg score  21.6 time steps 367 learning_steps 18
# episode 17 score 33.0 avg score  22.2 time steps 400 learning_steps 20
# episode 18 score 18.0 avg score  22.0 time steps 418 learning_steps 20
# episode 19 score 13.0 avg score  21.6 time steps 431 learning_steps 21
# episode 20 score 29.0 avg score  21.9 time steps 460 learning_steps 23
# episode 21 score 13.0 avg score  21.5 time steps 473 learning_steps 23
# episode 22 score 33.0 avg score  22.0 time steps 506 learning_steps 25
# episode 23 score 16.0 avg score  21.8 time steps 522 learning_steps 26
# episode 24 score 17.0 avg score  21.6 time steps 539 learning_steps 26
# episode 25 score 10.0 avg score  21.1 time steps 549 learning_steps 27
# episode 26 score 12.0 avg score  20.8 time steps 561 learning_steps 28
# episode 27 score 20.0 avg score  20.8 time steps 581 learning_steps 29
# episode 28 score 13.0 avg score  20.5 time steps 594 learning_steps 29
# episode 29 score 11.0 avg score  20.2 time steps 605 learning_steps 30
# episode 30 score 9.0 avg score  19.8 time steps 614 learning_steps 30
# episode 31 score 21.0 avg score  19.8 time steps 635 learning_steps 31
# episode 32 score 15.0 avg score  19.7 time steps 650 learning_steps 32
# episode 33 score 12.0 avg score  19.5 time steps 662 learning_steps 33
# episode 34 score 9.0 avg score  19.2 time steps 671 learning_steps 33
# episode 35 score 11.0 avg score  18.9 time steps 682 learning_steps 34
# episode 36 score 9.0 avg score  18.7 time steps 691 learning_steps 34
# episode 37 score 12.0 avg score  18.5 time steps 703 learning_steps 35
# episode 38 score 16.0 avg score  18.4 time steps 719 learning_steps 35
# episode 39 score 12.0 avg score  18.3 time steps 731 learning_steps 36
# episode 40 score 14.0 avg score  18.2 time steps 745 learning_steps 37
# episode 41 score 11.0 avg score  18.0 time steps 756 learning_steps 37
# episode 42 score 17.0 avg score  18.0 time steps 773 learning_steps 38
# episode 43 score 10.0 avg score  17.8 time steps 783 learning_steps 39
# episode 44 score 21.0 avg score  17.9 time steps 804 learning_steps 40
# episode 45 score 12.0 avg score  17.7 time steps 816 learning_steps 40
# episode 46 score 8.0 avg score  17.5 time steps 824 learning_steps 41
# episode 47 score 14.0 avg score  17.5 time steps 838 learning_steps 41
# episode 48 score 25.0 avg score  17.6 time steps 863 learning_steps 43
# episode 49 score 16.0 avg score  17.6 time steps 879 learning_steps 43
# episode 50 score 21.0 avg score  17.6 time steps 900 learning_steps 45
# episode 51 score 15.0 avg score  17.6 time steps 915 learning_steps 45
# episode 52 score 16.0 avg score  17.6 time steps 931 learning_steps 46
# episode 53 score 12.0 avg score  17.5 time steps 943 learning_steps 47
# episode 54 score 13.0 avg score  17.4 time steps 956 learning_steps 47
# episode 55 score 21.0 avg score  17.4 time steps 977 learning_steps 48
# episode 56 score 9.0 avg score  17.3 time steps 986 learning_steps 49
# episode 57 score 16.0 avg score  17.3 time steps 1002 learning_steps 50
# episode 58 score 15.0 avg score  17.2 time steps 1017 learning_steps 50
# episode 59 score 14.0 avg score  17.2 time steps 1031 learning_steps 51
# episode 60 score 12.0 avg score  17.1 time steps 1043 learning_steps 52
# episode 61 score 15.0 avg score  17.1 time steps 1058 learning_steps 52
# episode 62 score 13.0 avg score  17.0 time steps 1071 learning_steps 53
# episode 63 score 12.0 avg score  16.9 time steps 1083 learning_steps 54
# episode 64 score 15.0 avg score  16.9 time steps 1098 learning_steps 54
# episode 65 score 17.0 avg score  16.9 time steps 1115 learning_steps 55
# episode 66 score 15.0 avg score  16.9 time steps 1130 learning_steps 56
# episode 67 score 15.0 avg score  16.8 time steps 1145 learning_steps 57
# episode 68 score 26.0 avg score  17.0 time steps 1171 learning_steps 58
# episode 69 score 17.0 avg score  17.0 time steps 1188 learning_steps 59
# episode 70 score 10.0 avg score  16.9 time steps 1198 learning_steps 59
# episode 71 score 15.0 avg score  16.8 time steps 1213 learning_steps 60
# episode 72 score 11.0 avg score  16.8 time steps 1224 learning_steps 61
# episode 73 score 20.0 avg score  16.8 time steps 1244 learning_steps 62
# episode 74 score 13.0 avg score  16.8 time steps 1257 learning_steps 62
# episode 75 score 24.0 avg score  16.9 time steps 1281 learning_steps 64
# episode 76 score 11.0 avg score  16.8 time steps 1292 learning_steps 64
# episode 77 score 18.0 avg score  16.8 time steps 1310 learning_steps 65
# episode 78 score 11.0 avg score  16.7 time steps 1321 learning_steps 66
# episode 79 score 10.0 avg score  16.6 time steps 1331 learning_steps 66
# episode 80 score 16.0 avg score  16.6 time steps 1347 learning_steps 67
# episode 81 score 10.0 avg score  16.5 time steps 1357 learning_steps 67
# episode 82 score 14.0 avg score  16.5 time steps 1371 learning_steps 68
# episode 83 score 16.0 avg score  16.5 time steps 1387 learning_steps 69
# episode 84 score 18.0 avg score  16.5 time steps 1405 learning_steps 70
# episode 85 score 12.0 avg score  16.5 time steps 1417 learning_steps 70
# episode 86 score 25.0 avg score  16.6 time steps 1442 learning_steps 72
# episode 87 score 11.0 avg score  16.5 time steps 1453 learning_steps 72
# episode 88 score 10.0 avg score  16.4 time steps 1463 learning_steps 73
# episode 89 score 10.0 avg score  16.4 time steps 1473 learning_steps 73
# episode 90 score 13.0 avg score  16.3 time steps 1486 learning_steps 74
# episode 91 score 9.0 avg score  16.2 time steps 1495 learning_steps 74
# episode 92 score 11.0 avg score  16.2 time steps 1506 learning_steps 75
# episode 93 score 21.0 avg score  16.2 time steps 1527 learning_steps 76
# episode 94 score 12.0 avg score  16.2 time steps 1539 learning_steps 76
# episode 95 score 34.0 avg score  16.4 time steps 1573 learning_steps 78
# episode 96 score 15.0 avg score  16.4 time steps 1588 learning_steps 79
# episode 97 score 15.0 avg score  16.4 time steps 1603 learning_steps 80
# episode 98 score 12.0 avg score  16.3 time steps 1615 learning_steps 80
# episode 99 score 26.0 avg score  16.4 time steps 1641 learning_steps 82
# episode 100 score 13.0 avg score  16.1 time steps 1654 learning_steps 82
# episode 101 score 24.0 avg score  16.0 time steps 1678 learning_steps 83
# episode 102 score 31.0 avg score  16.2 time steps 1709 learning_steps 85
# episode 103 score 12.0 avg score  16.1 time steps 1721 learning_steps 86
# episode 104 score 15.0 avg score  15.9 time steps 1736 learning_steps 86
# episode 105 score 10.0 avg score  15.8 time steps 1746 learning_steps 87
# episode 106 score 21.0 avg score  15.9 time steps 1767 learning_steps 88
# episode 107 score 14.0 avg score  15.9 time steps 1781 learning_steps 89
# episode 108 score 10.0 avg score  15.8 time steps 1791 learning_steps 89
# episode 109 score 12.0 avg score  15.8 time steps 1803 learning_steps 90
# episode 110 score 12.0 avg score  15.6 time steps 1815 learning_steps 90
# episode 111 score 25.0 avg score  15.7 time steps 1840 learning_steps 92
# episode 112 score 14.0 avg score  15.7 time steps 1854 learning_steps 92
# episode 113 score 23.0 avg score  15.7 time steps 1877 learning_steps 93
# episode 114 score 13.0 avg score  15.7 time steps 1890 learning_steps 94
# episode 115 score 13.0 avg score  15.7 time steps 1903 learning_steps 95
# episode 116 score 12.0 avg score  15.5 time steps 1915 learning_steps 95
# episode 117 score 15.0 avg score  15.3 time steps 1930 learning_steps 96
# episode 118 score 9.0 avg score  15.2 time steps 1939 learning_steps 96
# episode 119 score 14.0 avg score  15.2 time steps 1953 learning_steps 97
# episode 120 score 11.0 avg score  15.0 time steps 1964 learning_steps 98
# episode 121 score 20.0 avg score  15.1 time steps 1984 learning_steps 99
# episode 122 score 12.0 avg score  14.9 time steps 1996 learning_steps 99
# episode 123 score 9.0 avg score  14.8 time steps 2005 learning_steps 100
# episode 124 score 14.0 avg score  14.8 time steps 2019 learning_steps 100
# episode 125 score 26.0 avg score  15.0 time steps 2045 learning_steps 102
# episode 126 score 26.0 avg score  15.1 time steps 2071 learning_steps 103
# episode 127 score 21.0 avg score  15.1 time steps 2092 learning_steps 104
# episode 128 score 9.0 avg score  15.1 time steps 2101 learning_steps 105
# episode 129 score 14.0 avg score  15.1 time steps 2115 learning_steps 105
# episode 130 score 19.0 avg score  15.2 time steps 2134 learning_steps 106
# episode 131 score 19.0 avg score  15.2 time steps 2153 learning_steps 107
# episode 132 score 13.0 avg score  15.2 time steps 2166 learning_steps 108
# episode 133 score 14.0 avg score  15.2 time steps 2180 learning_steps 109
# episode 134 score 23.0 avg score  15.3 time steps 2203 learning_steps 110
# episode 135 score 20.0 avg score  15.4 time steps 2223 learning_steps 111
# episode 136 score 37.0 avg score  15.7 time steps 2260 learning_steps 113
# episode 137 score 10.0 avg score  15.7 time steps 2270 learning_steps 113
# episode 138 score 21.0 avg score  15.7 time steps 2291 learning_steps 114
# episode 139 score 14.0 avg score  15.7 time steps 2305 learning_steps 115
# episode 140 score 19.0 avg score  15.8 time steps 2324 learning_steps 116
# episode 141 score 18.0 avg score  15.9 time steps 2342 learning_steps 117
# episode 142 score 12.0 avg score  15.8 time steps 2354 learning_steps 117
# episode 143 score 13.0 avg score  15.8 time steps 2367 learning_steps 118
# episode 144 score 18.0 avg score  15.8 time steps 2385 learning_steps 119
# episode 145 score 11.0 avg score  15.8 time steps 2396 learning_steps 119
# episode 146 score 16.0 avg score  15.9 time steps 2412 learning_steps 120
# episode 147 score 26.0 avg score  16.0 time steps 2438 learning_steps 121
# episode 148 score 18.0 avg score  15.9 time steps 2456 learning_steps 122
# episode 149 score 13.0 avg score  15.9 time steps 2469 learning_steps 123
# episode 150 score 28.0 avg score  16.0 time steps 2497 learning_steps 124
# episode 151 score 15.0 avg score  16.0 time steps 2512 learning_steps 125
# episode 152 score 10.0 avg score  15.9 time steps 2522 learning_steps 126
# episode 153 score 33.0 avg score  16.1 time steps 2555 learning_steps 127
# episode 154 score 13.0 avg score  16.1 time steps 2568 learning_steps 128
# episode 155 score 17.0 avg score  16.1 time steps 2585 learning_steps 129
# episode 156 score 17.0 avg score  16.2 time steps 2602 learning_steps 130
# episode 157 score 23.0 avg score  16.2 time steps 2625 learning_steps 131
# episode 158 score 12.0 avg score  16.2 time steps 2637 learning_steps 131
# episode 159 score 10.0 avg score  16.2 time steps 2647 learning_steps 132
# episode 160 score 14.0 avg score  16.2 time steps 2661 learning_steps 133
# episode 161 score 59.0 avg score  16.6 time steps 2720 learning_steps 136
# episode 162 score 9.0 avg score  16.6 time steps 2729 learning_steps 136
# episode 163 score 34.0 avg score  16.8 time steps 2763 learning_steps 138
# episode 164 score 14.0 avg score  16.8 time steps 2777 learning_steps 138
# episode 165 score 12.0 avg score  16.7 time steps 2789 learning_steps 139
# episode 166 score 14.0 avg score  16.7 time steps 2803 learning_steps 140
# episode 167 score 12.0 avg score  16.7 time steps 2815 learning_steps 140
# episode 168 score 9.0 avg score  16.5 time steps 2824 learning_steps 141
# episode 169 score 9.0 avg score  16.4 time steps 2833 learning_steps 141
# episode 170 score 10.0 avg score  16.4 time steps 2843 learning_steps 142
# episode 171 score 10.0 avg score  16.4 time steps 2853 learning_steps 142
# episode 172 score 8.0 avg score  16.4 time steps 2861 learning_steps 143
# episode 173 score 9.0 avg score  16.3 time steps 2870 learning_steps 143
# episode 174 score 11.0 avg score  16.2 time steps 2881 learning_steps 144
# episode 175 score 21.0 avg score  16.2 time steps 2902 learning_steps 145
# episode 176 score 10.0 avg score  16.2 time steps 2912 learning_steps 145
# episode 177 score 9.0 avg score  16.1 time steps 2921 learning_steps 146
# episode 178 score 8.0 avg score  16.1 time steps 2929 learning_steps 146
# episode 179 score 9.0 avg score  16.1 time steps 2938 learning_steps 146
# episode 180 score 10.0 avg score  16.0 time steps 2948 learning_steps 147
# episode 181 score 9.0 avg score  16.0 time steps 2957 learning_steps 147
# episode 182 score 10.0 avg score  16.0 time steps 2967 learning_steps 148
# episode 183 score 10.0 avg score  15.9 time steps 2977 learning_steps 148
# episode 184 score 8.0 avg score  15.8 time steps 2985 learning_steps 149
# episode 185 score 9.0 avg score  15.8 time steps 2994 learning_steps 149
# episode 186 score 10.0 avg score  15.6 time steps 3004 learning_steps 150
# episode 187 score 9.0 avg score  15.6 time steps 3013 learning_steps 150
# episode 188 score 10.0 avg score  15.6 time steps 3023 learning_steps 151
# episode 189 score 12.0 avg score  15.6 time steps 3035 learning_steps 151
# episode 190 score 10.0 avg score  15.6 time steps 3045 learning_steps 152
# episode 191 score 9.0 avg score  15.6 time steps 3054 learning_steps 152
# episode 192 score 10.0 avg score  15.6 time steps 3064 learning_steps 153
# episode 193 score 22.0 avg score  15.6 time steps 3086 learning_steps 154
# episode 194 score 9.0 avg score  15.6 time steps 3095 learning_steps 154
# episode 195 score 14.0 avg score  15.4 time steps 3109 learning_steps 155
# episode 196 score 8.0 avg score  15.3 time steps 3117 learning_steps 155
# episode 197 score 13.0 avg score  15.3 time steps 3130 learning_steps 156
# episode 198 score 9.0 avg score  15.2 time steps 3139 learning_steps 156
# episode 199 score 13.0 avg score  15.1 time steps 3152 learning_steps 157
# episode 200 score 12.0 avg score  15.1 time steps 3164 learning_steps 158
# episode 201 score 10.0 avg score  15.0 time steps 3174 learning_steps 158
# episode 202 score 10.0 avg score  14.8 time steps 3184 learning_steps 159
# episode 203 score 9.0 avg score  14.7 time steps 3193 learning_steps 159
# episode 204 score 8.0 avg score  14.7 time steps 3201 learning_steps 160
# episode 205 score 14.0 avg score  14.7 time steps 3215 learning_steps 160
# episode 206 score 11.0 avg score  14.6 time steps 3226 learning_steps 161
# episode 207 score 9.0 avg score  14.5 time steps 3235 learning_steps 161
# episode 208 score 10.0 avg score  14.5 time steps 3245 learning_steps 162
# episode 209 score 8.0 avg score  14.5 time steps 3253 learning_steps 162
# episode 210 score 11.0 avg score  14.5 time steps 3264 learning_steps 163
# episode 211 score 12.0 avg score  14.4 time steps 3276 learning_steps 163
# episode 212 score 10.0 avg score  14.3 time steps 3286 learning_steps 164
# episode 213 score 10.0 avg score  14.2 time steps 3296 learning_steps 164
# episode 214 score 8.0 avg score  14.1 time steps 3304 learning_steps 165
# episode 215 score 9.0 avg score  14.1 time steps 3313 learning_steps 165
# episode 216 score 11.0 avg score  14.1 time steps 3324 learning_steps 166
# episode 217 score 9.0 avg score  14.0 time steps 3333 learning_steps 166
# episode 218 score 8.0 avg score  14.0 time steps 3341 learning_steps 167
# episode 219 score 10.0 avg score  14.0 time steps 3351 learning_steps 167
# episode 220 score 8.0 avg score  13.9 time steps 3359 learning_steps 167
# episode 221 score 10.0 avg score  13.8 time steps 3369 learning_steps 168
# episode 222 score 10.0 avg score  13.8 time steps 3379 learning_steps 168
# episode 223 score 15.0 avg score  13.9 time steps 3394 learning_steps 169
# episode 224 score 8.0 avg score  13.8 time steps 3402 learning_steps 170
# episode 225 score 9.0 avg score  13.7 time steps 3411 learning_steps 170
# episode 226 score 13.0 avg score  13.5 time steps 3424 learning_steps 171
# episode 227 score 10.0 avg score  13.4 time steps 3434 learning_steps 171
# episode 228 score 9.0 avg score  13.4 time steps 3443 learning_steps 172
# episode 229 score 10.0 avg score  13.4 time steps 3453 learning_steps 172
# episode 230 score 8.0 avg score  13.3 time steps 3461 learning_steps 173
# episode 231 score 12.0 avg score  13.2 time steps 3473 learning_steps 173
# episode 232 score 11.0 avg score  13.2 time steps 3484 learning_steps 174
# episode 233 score 9.0 avg score  13.1 time steps 3493 learning_steps 174
# episode 234 score 9.0 avg score  13.0 time steps 3502 learning_steps 175
# episode 235 score 10.0 avg score  12.9 time steps 3512 learning_steps 175
# episode 236 score 9.0 avg score  12.6 time steps 3521 learning_steps 176
# episode 237 score 10.0 avg score  12.6 time steps 3531 learning_steps 176
# episode 238 score 11.0 avg score  12.5 time steps 3542 learning_steps 177
# episode 239 score 9.0 avg score  12.5 time steps 3551 learning_steps 177
# episode 240 score 9.0 avg score  12.4 time steps 3560 learning_steps 178
# episode 241 score 10.0 avg score  12.3 time steps 3570 learning_steps 178
# episode 242 score 10.0 avg score  12.3 time steps 3580 learning_steps 179
# episode 243 score 9.0 avg score  12.2 time steps 3589 learning_steps 179
# episode 244 score 17.0 avg score  12.2 time steps 3606 learning_steps 180
# episode 245 score 10.0 avg score  12.2 time steps 3616 learning_steps 180
# episode 246 score 10.0 avg score  12.1 time steps 3626 learning_steps 181
# episode 247 score 9.0 avg score  12.0 time steps 3635 learning_steps 181
# episode 248 score 9.0 avg score  11.9 time steps 3644 learning_steps 182
# episode 249 score 10.0 avg score  11.8 time steps 3654 learning_steps 182
# episode 250 score 9.0 avg score  11.7 time steps 3663 learning_steps 183
# episode 251 score 12.0 avg score  11.6 time steps 3675 learning_steps 183
# episode 252 score 9.0 avg score  11.6 time steps 3684 learning_steps 184
# episode 253 score 9.0 avg score  11.4 time steps 3693 learning_steps 184
# episode 254 score 10.0 avg score  11.3 time steps 3703 learning_steps 185
# episode 255 score 9.0 avg score  11.3 time steps 3712 learning_steps 185
# episode 256 score 10.0 avg score  11.2 time steps 3722 learning_steps 186
# episode 257 score 9.0 avg score  11.1 time steps 3731 learning_steps 186
# episode 258 score 11.0 avg score  11.1 time steps 3742 learning_steps 187
# episode 259 score 9.0 avg score  11.0 time steps 3751 learning_steps 187
# episode 260 score 10.0 avg score  11.0 time steps 3761 learning_steps 188
# episode 261 score 10.0 avg score  10.5 time steps 3771 learning_steps 188
# episode 262 score 9.0 avg score  10.5 time steps 3780 learning_steps 189
# episode 263 score 9.0 avg score  10.3 time steps 3789 learning_steps 189
# episode 264 score 10.0 avg score  10.2 time steps 3799 learning_steps 189
# episode 265 score 11.0 avg score  10.2 time steps 3810 learning_steps 190
# episode 266 score 10.0 avg score  10.2 time steps 3820 learning_steps 191
# episode 267 score 9.0 avg score  10.1 time steps 3829 learning_steps 191
# episode 268 score 10.0 avg score  10.2 time steps 3839 learning_steps 191
# episode 269 score 10.0 avg score  10.2 time steps 3849 learning_steps 192
# episode 270 score 9.0 avg score  10.2 time steps 3858 learning_steps 192
# episode 271 score 9.0 avg score  10.1 time steps 3867 learning_steps 193
# episode 272 score 9.0 avg score  10.2 time steps 3876 learning_steps 193
# episode 273 score 10.0 avg score  10.2 time steps 3886 learning_steps 194
# episode 274 score 11.0 avg score  10.2 time steps 3897 learning_steps 194
# episode 275 score 9.0 avg score  10.0 time steps 3906 learning_steps 195
# episode 276 score 10.0 avg score  10.0 time steps 3916 learning_steps 195
# episode 277 score 10.0 avg score  10.1 time steps 3926 learning_steps 196
# episode 278 score 9.0 avg score  10.1 time steps 3935 learning_steps 196
# episode 279 score 10.0 avg score  10.1 time steps 3945 learning_steps 197
# episode 280 score 9.0 avg score  10.1 time steps 3954 learning_steps 197
# episode 281 score 10.0 avg score  10.1 time steps 3964 learning_steps 198
# episode 282 score 9.0 avg score  10.1 time steps 3973 learning_steps 198
# episode 283 score 12.0 avg score  10.1 time steps 3985 learning_steps 199
# episode 284 score 9.0 avg score  10.1 time steps 3994 learning_steps 199
# episode 285 score 10.0 avg score  10.1 time steps 4004 learning_steps 200
# episode 286 score 10.0 avg score  10.1 time steps 4014 learning_steps 200
# episode 287 score 10.0 avg score  10.1 time steps 4024 learning_steps 201
# episode 288 score 8.0 avg score  10.1 time steps 4032 learning_steps 201
# episode 289 score 8.0 avg score  10.1 time steps 4040 learning_steps 202
# episode 290 score 10.0 avg score  10.1 time steps 4050 learning_steps 202
# episode 291 score 9.0 avg score  10.1 time steps 4059 learning_steps 202
# episode 292 score 10.0 avg score  10.1 time steps 4069 learning_steps 203
# episode 293 score 9.0 avg score  9.9 time steps 4078 learning_steps 203
# episode 294 score 9.0 avg score  9.9 time steps 4087 learning_steps 204
# episode 295 score 10.0 avg score  9.9 time steps 4097 learning_steps 204
# episode 296 score 9.0 avg score  9.9 time steps 4106 learning_steps 205
# episode 297 score 9.0 avg score  9.8 time steps 4115 learning_steps 205
# episode 298 score 10.0 avg score  9.9 time steps 4125 learning_steps 206
# episode 299 score 10.0 avg score  9.8 time steps 4135 learning_steps 206
